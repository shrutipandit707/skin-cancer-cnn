# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.utils import get_file
from sklearn.metrics import roc_curve, auc, confusion_matrix
#from imblearn.metrics import sensitivity_score, specificity_score

import os
import glob
import zipfile
import random

# %%
# to get consistent results after multiple runs
tf.random.set_seed(7)
np.random.seed(7)
random.seed(7)

# 0 for benign, 1 for malignant
class_names = ["benign", "malignant"]

# %%
def download_and_extract_dataset():
  # dataset from https://github.com/udacity/dermatologist-ai
  # 5.3GB
  train_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip"
  # 824.5MB
  valid_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip"
  # 5.1GB
  test_url  = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip"
  for i, download_link in enumerate([valid_url, train_url, test_url]):
    temp_file = f"temp{i}.zip"
    data_dir = get_file(origin=download_link, fname=os.path.join(os.getcwd(), temp_file))
    print("Extracting", download_link)
    with zipfile.ZipFile(data_dir, "r") as z:
      z.extractall("data")
    # remove the temp file
    os.remove(temp_file)

# comment the below line if you already downloaded the dataset
download_and_extract_dataset()
# Out:
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# 864538487/864538487 [==============================] - 662s 1us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# 5736557430/5736557430 [==============================] - 5817s 1us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip
# 5528640507/5528640507 [==============================] - 5608s 1us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip

# %%
# preparing data
# generate CSV metadata file to read img paths and labels from it
def generate_csv(folder, label2int):
    folder_name = os.path.basename(folder)
    labels = list(label2int)
    # generate CSV file
    df = pd.DataFrame(columns=["filepath", "label"])
    i = 0
    for label in labels:
        print("Reading", os.path.join(folder, label, "*"))
        for filepath in glob.glob(os.path.join(folder, label, "*")):
            df.loc[i] = [filepath, label2int[label]]
            i += 1
    output_file = f"{folder_name}.csv"
    print("Saving", output_file)
    df.to_csv(output_file)

# generate CSV files for all data portions, labeling nevus and seborrheic keratosis
# as 0 (benign), and melanoma as 1 (malignant)
# you should replace "data" path to your extracted dataset path
# don't replace if you used download_and_extract_dataset() function
generate_csv("data/train", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/valid", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/test", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
# Out:
# Reading data/train\nevus\*
# Reading data/train\seborrheic_keratosis\*
# Reading data/train\melanoma\*
# Saving train.csv
# Reading data/valid\nevus\*
# Reading data/valid\seborrheic_keratosis\*
# Reading data/valid\melanoma\*
# Saving valid.csv
# Reading data/test\nevus\*
# Reading data/test\seborrheic_keratosis\*
# Reading data/test\melanoma\*
# Saving test.csv

# %%
# loading data
train_metadata_filename = "train.csv"
valid_metadata_filename = "valid.csv"
# load CSV files as DataFrames
df_train = pd.read_csv(train_metadata_filename)
df_valid = pd.read_csv(valid_metadata_filename)
n_training_samples = len(df_train)
n_validation_samples = len(df_valid)
print("Number of training samples:", n_training_samples)
print("Number of validation samples:", n_validation_samples)
train_ds = tf.data.Dataset.from_tensor_slices((df_train["filepath"], df_train["label"]))
valid_ds = tf.data.Dataset.from_tensor_slices((df_valid["filepath"], df_valid["label"]))
# Out:
# Number of training samples: 2000
# Number of validation samples: 150

# %%
# preprocess data
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, [299, 299])


def process_path(filepath, label):
  # load the raw data from the file as a string
  img = tf.io.read_file(filepath)
  img = decode_img(img)
  return img, label


valid_ds = valid_ds.map(process_path)
train_ds = train_ds.map(process_path)
# test_ds = test_ds
# for image, label in train_ds.take(1):
#     print("Image shape:", image.shape)
#     print("Label:", label.numpy())

# %%
# training parameters
batch_size = 64
optimizer = "rmsprop"

# %%
def prepare_for_training(ds, cache=True, batch_size=64, shuffle_buffer_size=1000):
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()
  # shuffle the dataset
  ds = ds.shuffle(buffer_size=shuffle_buffer_size)

  # Repeat forever
  ds = ds.repeat()
  # split to batches
  ds = ds.batch(batch_size)

  # `prefetch` lets the dataset fetch batches in the background while the model
  # is training.
  ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

  return ds


valid_ds = prepare_for_training(valid_ds, batch_size=batch_size, cache="valid-cached-data")
train_ds = prepare_for_training(train_ds, batch_size=batch_size, cache="train-cached-data")

# %%
batch = next(iter(valid_ds))

def show_batch(batch):
  plt.figure(figsize=(12,12))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(batch[0][n])
      plt.title(class_names[batch[1][n].numpy()].title())
      plt.axis('off')
        
show_batch(batch)

# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.utils import get_file
from sklearn.metrics import roc_curve, auc, confusion_matrix

# %%
# building the model
# InceptionV3 model & pre-trained weights
module_url = "https://tfhub.dev/google/tf2-preview/inception_v3/feature_vector/4"
m = tf.keras.Sequential([
    hub.KerasLayer(module_url, output_shape=[2048], trainable=False),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

m.build([None, 299, 299, 3])
m.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 2048)              21802784
#
#  dense (Dense)               (None, 1)                 2049
#
# =================================================================
# Total params: 21,804,833
# Trainable params: 2,049
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
model_name = f"benign-vs-malignant_{batch_size}_{optimizer}"
tensorboard = tf.keras.callbacks.TensorBoard(log_dir=os.path.join("logs", model_name))
# saves model checkpoint whenever we reach better weights
modelcheckpoint = tf.keras.callbacks.ModelCheckpoint(model_name + "_{val_loss:.3f}.h5", save_best_only=True, verbose=1)

history = m.fit(train_ds, validation_data=valid_ds, 
                steps_per_epoch=n_training_samples // batch_size, 
                validation_steps=n_validation_samples // batch_size, verbose=1, epochs=100,
                callbacks=[tensorboard, modelcheckpoint])
# Out:
# Epoch 1/100
# 31/31 [==============================] - ETA: 0s - loss: 0.4600 - accuracy: 0.7707
# Epoch 1: val_loss improved from inf to 0.57842, saving model to benign-vs-malignant_64_rmsprop_0.578.h5
# 31/31 [==============================] - 259s 7s/step - loss: 0.4600 - accuracy: 0.7707 - val_loss: 0.5784 - val_accuracy: 0.7734
# Epoch 2/100
# 31/31 [==============================] - ETA: 0s - loss: 0.4077 - accuracy: 0.8070
# Epoch 2: val_loss improved from 0.57842 to 0.50465, saving model to benign-vs-malignant_64_rmsprop_0.505.h5
# 31/31 [==============================] - 175s 6s/step - loss: 0.4077 - accuracy: 0.8070 - val_loss: 0.5047 - val_accuracy: 0.7969
# Epoch 3/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3871 - accuracy: 0.8251
# Epoch 3: val_loss improved from 0.50465 to 0.47657, saving model to benign-vs-malignant_64_rmsprop_0.477.h5
# 31/31 [==============================] - 179s 6s/step - loss: 0.3871 - accuracy: 0.8251 - val_loss: 0.4766 - val_accuracy: 0.8203
# Epoch 4/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3714 - accuracy: 0.8261
# Epoch 4: val_loss did not improve from 0.47657
# 31/31 [==============================] - 182s 6s/step - loss: 0.3714 - accuracy: 0.8261 - val_loss: 0.4893 - val_accuracy: 0.7812
# Epoch 5/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3565 - accuracy: 0.8322
# Epoch 5: val_loss improved from 0.47657 to 0.45809, saving model to benign-vs-malignant_64_rmsprop_0.458.h5
# 31/31 [==============================] - 186s 6s/step - loss: 0.3565 - accuracy: 0.8322 - val_loss: 0.4581 - val_accuracy: 0.7891
# Epoch 6/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3497 - accuracy: 0.8402
# Epoch 6: val_loss did not improve from 0.45809
# 31/31 [==============================] - 183s 6s/step - loss: 0.3497 - accuracy: 0.8402 - val_loss: 0.4607 - val_accuracy: 0.7969
# Epoch 7/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3469 - accuracy: 0.8407
# Epoch 7: val_loss improved from 0.45809 to 0.44589, saving model to benign-vs-malignant_64_rmsprop_0.446.h5
# 31/31 [==============================] - 183s 6s/step - loss: 0.3469 - accuracy: 0.8407 - val_loss: 0.4459 - val_accuracy: 0.7969
# Epoch 8/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3390 - accuracy: 0.8422
# Epoch 8: val_loss improved from 0.44589 to 0.43190, saving model to benign-vs-malignant_64_rmsprop_0.432.h5
# 31/31 [==============================] - 183s 6s/step - loss: 0.3390 - accuracy: 0.8422 - val_loss: 0.4319 - val_accuracy: 0.8125
# Epoch 9/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3491 - accuracy: 0.8417
# Epoch 9: val_loss did not improve from 0.43190
# 31/31 [==============================] - 175s 6s/step - loss: 0.3491 - accuracy: 0.8417 - val_loss: 0.4413 - val_accuracy: 0.8047
# Epoch 10/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3164 - accuracy: 0.8639
# Epoch 10: val_loss did not improve from 0.43190
# 31/31 [==============================] - 176s 6s/step - loss: 0.3164 - accuracy: 0.8639 - val_loss: 0.4825 - val_accuracy: 0.7734
# Epoch 11/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3139 - accuracy: 0.8634
# Epoch 11: val_loss did not improve from 0.43190
# 31/31 [==============================] - 177s 6s/step - loss: 0.3139 - accuracy: 0.8634 - val_loss: 0.4599 - val_accuracy: 0.7969
# Epoch 12/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3314 - accuracy: 0.8548
# Epoch 12: val_loss did not improve from 0.43190
# 31/31 [==============================] - 176s 6s/step - loss: 0.3314 - accuracy: 0.8548 - val_loss: 0.4510 - val_accuracy: 0.8281
# Epoch 13/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3373 - accuracy: 0.8427
# Epoch 13: val_loss did not improve from 0.43190
# 31/31 [==============================] - 180s 6s/step - loss: 0.3373 - accuracy: 0.8427 - val_loss: 0.4501 - val_accuracy: 0.8047
# Epoch 14/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3092 - accuracy: 0.8654
# Epoch 14: val_loss did not improve from 0.43190
# 31/31 [==============================] - 176s 6s/step - loss: 0.3092 - accuracy: 0.8654 - val_loss: 0.5152 - val_accuracy: 0.7266
# Epoch 15/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3176 - accuracy: 0.8604
# Epoch 15: val_loss did not improve from 0.43190
# 31/31 [==============================] - 173s 6s/step - loss: 0.3176 - accuracy: 0.8604 - val_loss: 0.4529 - val_accuracy: 0.8203
# Epoch 16/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3205 - accuracy: 0.8609
# Epoch 16: val_loss did not improve from 0.43190
# 31/31 [==============================] - 174s 6s/step - loss: 0.3205 - accuracy: 0.8609 - val_loss: 0.4591 - val_accuracy: 0.7812
# Epoch 17/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3208 - accuracy: 0.8488
# Epoch 17: val_loss did not improve from 0.43190
# 31/31 [==============================] - 177s 6s/step - loss: 0.3208 - accuracy: 0.8488 - val_loss: 0.4904 - val_accuracy: 0.7578
# Epoch 18/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3055 - accuracy: 0.8629
# Epoch 18: val_loss did not improve from 0.43190
# 31/31 [==============================] - 179s 6s/step - loss: 0.3055 - accuracy: 0.8629 - val_loss: 0.5100 - val_accuracy: 0.6953
# Epoch 19/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3138 - accuracy: 0.8599
# Epoch 19: val_loss improved from 0.43190 to 0.42465, saving model to benign-vs-malignant_64_rmsprop_0.425.h5
# 31/31 [==============================] - 181s 6s/step - loss: 0.3138 - accuracy: 0.8599 - val_loss: 0.4246 - val_accuracy: 0.8047
# Epoch 20/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2935 - accuracy: 0.8669
# Epoch 20: val_loss did not improve from 0.42465
# 31/31 [==============================] - 180s 6s/step - loss: 0.2935 - accuracy: 0.8669 - val_loss: 0.4479 - val_accuracy: 0.8125
# Epoch 21/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3001 - accuracy: 0.8624
# Epoch 21: val_loss improved from 0.42465 to 0.41944, saving model to benign-vs-malignant_64_rmsprop_0.419.h5
# 31/31 [==============================] - 180s 6s/step - loss: 0.3001 - accuracy: 0.8624 - val_loss: 0.4194 - val_accuracy: 0.8047
# Epoch 22/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3030 - accuracy: 0.8710
# Epoch 22: val_loss did not improve from 0.41944
# 31/31 [==============================] - 182s 6s/step - loss: 0.3030 - accuracy: 0.8710 - val_loss: 0.4651 - val_accuracy: 0.7891
# Epoch 23/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2938 - accuracy: 0.8730
# Epoch 23: val_loss did not improve from 0.41944
# 31/31 [==============================] - 182s 6s/step - loss: 0.2938 - accuracy: 0.8730 - val_loss: 0.4649 - val_accuracy: 0.8047
# Epoch 24/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2899 - accuracy: 0.8710
# Epoch 24: val_loss did not improve from 0.41944
# 31/31 [==============================] - 183s 6s/step - loss: 0.2899 - accuracy: 0.8710 - val_loss: 0.4740 - val_accuracy: 0.7969
# Epoch 25/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2924 - accuracy: 0.8805
# Epoch 25: val_loss did not improve from 0.41944
# 31/31 [==============================] - 181s 6s/step - loss: 0.2924 - accuracy: 0.8805 - val_loss: 0.4617 - val_accuracy: 0.8047
# Epoch 26/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3001 - accuracy: 0.8710
# Epoch 26: val_loss did not improve from 0.41944
# 31/31 [==============================] - 185s 6s/step - loss: 0.3001 - accuracy: 0.8710 - val_loss: 0.4554 - val_accuracy: 0.8203
# Epoch 27/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2856 - accuracy: 0.8735
# Epoch 27: val_loss did not improve from 0.41944
# 31/31 [==============================] - 189s 6s/step - loss: 0.2856 - accuracy: 0.8735 - val_loss: 0.4385 - val_accuracy: 0.8047
# Epoch 28/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2754 - accuracy: 0.8841
# Epoch 28: val_loss did not improve from 0.41944
# 31/31 [==============================] - 248s 8s/step - loss: 0.2754 - accuracy: 0.8841 - val_loss: 0.4481 - val_accuracy: 0.8359
# Epoch 29/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3031 - accuracy: 0.8604
# Epoch 29: val_loss did not improve from 0.41944
# 31/31 [==============================] - 243s 8s/step - loss: 0.3031 - accuracy: 0.8604 - val_loss: 0.4389 - val_accuracy: 0.8438
# Epoch 30/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2801 - accuracy: 0.8760
# Epoch 30: val_loss did not improve from 0.41944
# 31/31 [==============================] - 244s 8s/step - loss: 0.2801 - accuracy: 0.8760 - val_loss: 0.4342 - val_accuracy: 0.8203
# Epoch 31/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2811 - accuracy: 0.8810
# Epoch 31: val_loss did not improve from 0.41944
# 31/31 [==============================] - 175s 6s/step - loss: 0.2811 - accuracy: 0.8810 - val_loss: 0.4537 - val_accuracy: 0.8125
# Epoch 32/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2826 - accuracy: 0.8881
# Epoch 32: val_loss improved from 0.41944 to 0.37129, saving model to benign-vs-malignant_64_rmsprop_0.371.h5
# 31/31 [==============================] - 200s 6s/step - loss: 0.2826 - accuracy: 0.8881 - val_loss: 0.3713 - val_accuracy: 0.8438
# Epoch 33/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2649 - accuracy: 0.8906
# Epoch 33: val_loss did not improve from 0.37129
# 31/31 [==============================] - 169s 5s/step - loss: 0.2649 - accuracy: 0.8906 - val_loss: 0.4167 - val_accuracy: 0.7969
# Epoch 34/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2769 - accuracy: 0.8750
# Epoch 34: val_loss did not improve from 0.37129
# 31/31 [==============================] - 167s 5s/step - loss: 0.2769 - accuracy: 0.8750 - val_loss: 0.4898 - val_accuracy: 0.7656
# Epoch 35/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2831 - accuracy: 0.8745
# Epoch 35: val_loss did not improve from 0.37129
# 31/31 [==============================] - 168s 5s/step - loss: 0.2831 - accuracy: 0.8745 - val_loss: 0.4324 - val_accuracy: 0.7969
# Epoch 36/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2757 - accuracy: 0.8861
# Epoch 36: val_loss did not improve from 0.37129
# 31/31 [==============================] - 169s 5s/step - loss: 0.2757 - accuracy: 0.8861 - val_loss: 0.4191 - val_accuracy: 0.8203
# Epoch 37/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.8795
# Epoch 37: val_loss did not improve from 0.37129
# 31/31 [==============================] - 172s 6s/step - loss: 0.2817 - accuracy: 0.8795 - val_loss: 0.4619 - val_accuracy: 0.8203
# Epoch 38/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2797 - accuracy: 0.8805
# Epoch 38: val_loss did not improve from 0.37129
# 31/31 [==============================] - 171s 6s/step - loss: 0.2797 - accuracy: 0.8805 - val_loss: 0.4944 - val_accuracy: 0.7500
# Epoch 39/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2635 - accuracy: 0.8866
# Epoch 39: val_loss did not improve from 0.37129
# 31/31 [==============================] - 177s 6s/step - loss: 0.2635 - accuracy: 0.8866 - val_loss: 0.4377 - val_accuracy: 0.8125
# Epoch 40/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2655 - accuracy: 0.8952
# Epoch 40: val_loss did not improve from 0.37129
# 31/31 [==============================] - 182s 6s/step - loss: 0.2655 - accuracy: 0.8952 - val_loss: 0.4158 - val_accuracy: 0.8203
# Epoch 41/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2793 - accuracy: 0.8836
# Epoch 41: val_loss did not improve from 0.37129
# 31/31 [==============================] - 181s 6s/step - loss: 0.2793 - accuracy: 0.8836 - val_loss: 0.4854 - val_accuracy: 0.7969
# Epoch 42/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2716 - accuracy: 0.8841
# Epoch 42: val_loss did not improve from 0.37129
# 31/31 [==============================] - 183s 6s/step - loss: 0.2716 - accuracy: 0.8841 - val_loss: 0.4398 - val_accuracy: 0.8125
# Epoch 43/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.8795
# Epoch 43: val_loss did not improve from 0.37129
# 31/31 [==============================] - 185s 6s/step - loss: 0.2762 - accuracy: 0.8795 - val_loss: 0.5122 - val_accuracy: 0.7812
# Epoch 44/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2643 - accuracy: 0.8856
# Epoch 44: val_loss did not improve from 0.37129
# 31/31 [==============================] - 181s 6s/step - loss: 0.2643 - accuracy: 0.8856 - val_loss: 0.4494 - val_accuracy: 0.8125
# Epoch 45/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2735 - accuracy: 0.8785
# Epoch 45: val_loss did not improve from 0.37129
# 31/31 [==============================] - 180s 6s/step - loss: 0.2735 - accuracy: 0.8785 - val_loss: 0.4529 - val_accuracy: 0.8203
# Epoch 46/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2473 - accuracy: 0.8997
# Epoch 46: val_loss did not improve from 0.37129
# 31/31 [==============================] - 181s 6s/step - loss: 0.2473 - accuracy: 0.8997 - val_loss: 0.4647 - val_accuracy: 0.7891
# Epoch 47/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2755 - accuracy: 0.8770
# Epoch 47: val_loss did not improve from 0.37129
# 31/31 [==============================] - 182s 6s/step - loss: 0.2755 - accuracy: 0.8770 - val_loss: 0.4641 - val_accuracy: 0.8047
# Epoch 48/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2624 - accuracy: 0.8891
# Epoch 48: val_loss did not improve from 0.37129
# 31/31 [==============================] - 177s 6s/step - loss: 0.2624 - accuracy: 0.8891 - val_loss: 0.4522 - val_accuracy: 0.8125
# Epoch 49/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2633 - accuracy: 0.8856
# Epoch 49: val_loss did not improve from 0.37129
# 31/31 [==============================] - 197s 6s/step - loss: 0.2633 - accuracy: 0.8856 - val_loss: 0.4832 - val_accuracy: 0.8203
# Epoch 50/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2494 - accuracy: 0.8962
# Epoch 50: val_loss did not improve from 0.37129
# 31/31 [==============================] - 200s 6s/step - loss: 0.2494 - accuracy: 0.8962 - val_loss: 0.4371 - val_accuracy: 0.8125
# Epoch 51/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2596 - accuracy: 0.8947
# Epoch 51: val_loss did not improve from 0.37129
# 31/31 [==============================] - 205s 7s/step - loss: 0.2596 - accuracy: 0.8947 - val_loss: 0.4235 - val_accuracy: 0.8438
# Epoch 52/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2541 - accuracy: 0.9017
# Epoch 52: val_loss did not improve from 0.37129
# 31/31 [==============================] - 191s 6s/step - loss: 0.2541 - accuracy: 0.9017 - val_loss: 0.4366 - val_accuracy: 0.8125
# Epoch 53/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2541 - accuracy: 0.8977
# Epoch 53: val_loss did not improve from 0.37129
# 31/31 [==============================] - 193s 6s/step - loss: 0.2541 - accuracy: 0.8977 - val_loss: 0.4469 - val_accuracy: 0.7969
# Epoch 54/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2634 - accuracy: 0.8926
# Epoch 54: val_loss did not improve from 0.37129
# 31/31 [==============================] - 192s 6s/step - loss: 0.2634 - accuracy: 0.8926 - val_loss: 0.4801 - val_accuracy: 0.7812
# Epoch 55/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2550 - accuracy: 0.8947
# Epoch 55: val_loss did not improve from 0.37129
# 31/31 [==============================] - 189s 6s/step - loss: 0.2550 - accuracy: 0.8947 - val_loss: 0.4826 - val_accuracy: 0.8203
# Epoch 56/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2458 - accuracy: 0.8972
# Epoch 56: val_loss did not improve from 0.37129
# 31/31 [==============================] - 192s 6s/step - loss: 0.2458 - accuracy: 0.8972 - val_loss: 0.4235 - val_accuracy: 0.8125
# Epoch 57/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2464 - accuracy: 0.8997
# Epoch 57: val_loss did not improve from 0.37129
# 31/31 [==============================] - 193s 6s/step - loss: 0.2464 - accuracy: 0.8997 - val_loss: 0.4769 - val_accuracy: 0.8125
# Epoch 58/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2439 - accuracy: 0.8997
# Epoch 58: val_loss did not improve from 0.37129
# 31/31 [==============================] - 219s 7s/step - loss: 0.2439 - accuracy: 0.8997 - val_loss: 0.4041 - val_accuracy: 0.8203
# Epoch 59/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2471 - accuracy: 0.8977
# Epoch 59: val_loss did not improve from 0.37129
# 31/31 [==============================] - 225s 7s/step - loss: 0.2471 - accuracy: 0.8977 - val_loss: 0.4942 - val_accuracy: 0.7891
# Epoch 60/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2500 - accuracy: 0.8926
# Epoch 60: val_loss did not improve from 0.37129
# 31/31 [==============================] - 221s 7s/step - loss: 0.2500 - accuracy: 0.8926 - val_loss: 0.4704 - val_accuracy: 0.7891
# Epoch 61/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2626 - accuracy: 0.8931
# Epoch 61: val_loss did not improve from 0.37129
# 31/31 [==============================] - 228s 7s/step - loss: 0.2626 - accuracy: 0.8931 - val_loss: 0.4612 - val_accuracy: 0.7656
# Epoch 62/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2485 - accuracy: 0.9007
# Epoch 62: val_loss did not improve from 0.37129
# 31/31 [==============================] - 224s 7s/step - loss: 0.2485 - accuracy: 0.9007 - val_loss: 0.4873 - val_accuracy: 0.8047
# Epoch 63/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2579 - accuracy: 0.8936
# Epoch 63: val_loss did not improve from 0.37129
# 31/31 [==============================] - 207s 7s/step - loss: 0.2579 - accuracy: 0.8936 - val_loss: 0.4552 - val_accuracy: 0.8203
# Epoch 64/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2376 - accuracy: 0.8997
# Epoch 64: val_loss did not improve from 0.37129
# 31/31 [==============================] - 209s 7s/step - loss: 0.2376 - accuracy: 0.8997 - val_loss: 0.5020 - val_accuracy: 0.8125
# Epoch 65/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2530 - accuracy: 0.8921
# Epoch 65: val_loss did not improve from 0.37129
# 31/31 [==============================] - 219s 7s/step - loss: 0.2530 - accuracy: 0.8921 - val_loss: 0.4597 - val_accuracy: 0.7969
# Epoch 66/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2276 - accuracy: 0.9113
# Epoch 66: val_loss did not improve from 0.37129
# 31/31 [==============================] - 212s 7s/step - loss: 0.2276 - accuracy: 0.9113 - val_loss: 0.4692 - val_accuracy: 0.8281
# Epoch 67/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2326 - accuracy: 0.9098
# Epoch 67: val_loss did not improve from 0.37129
# 31/31 [==============================] - 232s 8s/step - loss: 0.2326 - accuracy: 0.9098 - val_loss: 0.4924 - val_accuracy: 0.8203
# Epoch 68/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2508 - accuracy: 0.8972
# Epoch 68: val_loss did not improve from 0.37129
# 31/31 [==============================] - 231s 7s/step - loss: 0.2508 - accuracy: 0.8972 - val_loss: 0.4561 - val_accuracy: 0.8047
# Epoch 69/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2380 - accuracy: 0.9027
# Epoch 69: val_loss did not improve from 0.37129
# 31/31 [==============================] - 239s 8s/step - loss: 0.2380 - accuracy: 0.9027 - val_loss: 0.4248 - val_accuracy: 0.8281
# Epoch 70/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2465 - accuracy: 0.8982
# Epoch 70: val_loss did not improve from 0.37129
# 31/31 [==============================] - 233s 8s/step - loss: 0.2465 - accuracy: 0.8982 - val_loss: 0.4726 - val_accuracy: 0.7891
# Epoch 71/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2348 - accuracy: 0.9057
# Epoch 71: val_loss did not improve from 0.37129
# 31/31 [==============================] - 247s 8s/step - loss: 0.2348 - accuracy: 0.9057 - val_loss: 0.4776 - val_accuracy: 0.8438
# Epoch 72/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.8987
# Epoch 72: val_loss did not improve from 0.37129
# 31/31 [==============================] - 246s 8s/step - loss: 0.2450 - accuracy: 0.8987 - val_loss: 0.5080 - val_accuracy: 0.8203
# Epoch 73/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.9027
# Epoch 73: val_loss did not improve from 0.37129
# 31/31 [==============================] - 240s 8s/step - loss: 0.2429 - accuracy: 0.9027 - val_loss: 0.6749 - val_accuracy: 0.8047
# Epoch 74/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2409 - accuracy: 0.9073
# Epoch 74: val_loss did not improve from 0.37129
# 31/31 [==============================] - 218s 7s/step - loss: 0.2409 - accuracy: 0.9073 - val_loss: 0.4752 - val_accuracy: 0.8516
# Epoch 75/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.9083
# Epoch 75: val_loss did not improve from 0.37129
# 31/31 [==============================] - 217s 7s/step - loss: 0.2247 - accuracy: 0.9083 - val_loss: 0.6016 - val_accuracy: 0.8281
# Epoch 76/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2373 - accuracy: 0.9037
# Epoch 76: val_loss did not improve from 0.37129
# 31/31 [==============================] - 216s 7s/step - loss: 0.2373 - accuracy: 0.9037 - val_loss: 0.7576 - val_accuracy: 0.7891
# Epoch 77/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2453 - accuracy: 0.9027
# Epoch 77: val_loss did not improve from 0.37129
# 31/31 [==============================] - 223s 7s/step - loss: 0.2453 - accuracy: 0.9027 - val_loss: 0.6809 - val_accuracy: 0.8047
# Epoch 78/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2286 - accuracy: 0.9027
# Epoch 78: val_loss did not improve from 0.37129
# 31/31 [==============================] - 217s 7s/step - loss: 0.2286 - accuracy: 0.9027 - val_loss: 0.7158 - val_accuracy: 0.8047
# Epoch 79/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2257 - accuracy: 0.9088
# Epoch 79: val_loss did not improve from 0.37129
# 31/31 [==============================] - 208s 7s/step - loss: 0.2257 - accuracy: 0.9088 - val_loss: 0.8499 - val_accuracy: 0.7891
# Epoch 80/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2276 - accuracy: 0.9093
# Epoch 80: val_loss did not improve from 0.37129
# 31/31 [==============================] - 195s 6s/step - loss: 0.2276 - accuracy: 0.9093 - val_loss: 0.8875 - val_accuracy: 0.7891
# Epoch 81/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.8967
# Epoch 81: val_loss did not improve from 0.37129
# 31/31 [==============================] - 180s 6s/step - loss: 0.2394 - accuracy: 0.8967 - val_loss: 0.8291 - val_accuracy: 0.8047
# Epoch 82/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2260 - accuracy: 0.9163
# Epoch 82: val_loss did not improve from 0.37129
# 31/31 [==============================] - 179s 6s/step - loss: 0.2260 - accuracy: 0.9163 - val_loss: 0.8435 - val_accuracy: 0.7969
# Epoch 83/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2352 - accuracy: 0.9062
# Epoch 83: val_loss did not improve from 0.37129
# 31/31 [==============================] - 188s 6s/step - loss: 0.2352 - accuracy: 0.9062 - val_loss: 0.9122 - val_accuracy: 0.8047
# Epoch 84/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2371 - accuracy: 0.9078
# Epoch 84: val_loss did not improve from 0.37129
# 31/31 [==============================] - 180s 6s/step - loss: 0.2371 - accuracy: 0.9078 - val_loss: 0.8873 - val_accuracy: 0.7969
# Epoch 85/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2364 - accuracy: 0.9002
# Epoch 85: val_loss did not improve from 0.37129
# 31/31 [==============================] - 178s 6s/step - loss: 0.2364 - accuracy: 0.9002 - val_loss: 0.8144 - val_accuracy: 0.8125
# Epoch 86/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2272 - accuracy: 0.9088
# Epoch 86: val_loss did not improve from 0.37129
# 31/31 [==============================] - 178s 6s/step - loss: 0.2272 - accuracy: 0.9088 - val_loss: 0.9660 - val_accuracy: 0.7891
# Epoch 87/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.9042
# Epoch 87: val_loss did not improve from 0.37129
# 31/31 [==============================] - 181s 6s/step - loss: 0.2293 - accuracy: 0.9042 - val_loss: 0.8506 - val_accuracy: 0.8047
# Epoch 88/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2242 - accuracy: 0.9118
# Epoch 88: val_loss did not improve from 0.37129
# 31/31 [==============================] - 186s 6s/step - loss: 0.2242 - accuracy: 0.9118 - val_loss: 0.9752 - val_accuracy: 0.7812
# Epoch 89/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2371 - accuracy: 0.9103
# Epoch 89: val_loss did not improve from 0.37129
# 31/31 [==============================] - 187s 6s/step - loss: 0.2371 - accuracy: 0.9103 - val_loss: 0.8308 - val_accuracy: 0.8125
# Epoch 90/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2300 - accuracy: 0.9002
# Epoch 90: val_loss did not improve from 0.37129
# 31/31 [==============================] - 189s 6s/step - loss: 0.2300 - accuracy: 0.9002 - val_loss: 0.7612 - val_accuracy: 0.8125
# Epoch 91/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2299 - accuracy: 0.9113
# Epoch 91: val_loss did not improve from 0.37129
# 31/31 [==============================] - 190s 6s/step - loss: 0.2299 - accuracy: 0.9113 - val_loss: 0.8413 - val_accuracy: 0.8125
# Epoch 92/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.9068
# Epoch 92: val_loss did not improve from 0.37129
# 31/31 [==============================] - 193s 6s/step - loss: 0.2293 - accuracy: 0.9068 - val_loss: 0.8987 - val_accuracy: 0.7969
# Epoch 93/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2418 - accuracy: 0.9012
# Epoch 93: val_loss did not improve from 0.37129
# 31/31 [==============================] - 192s 6s/step - loss: 0.2418 - accuracy: 0.9012 - val_loss: 0.8140 - val_accuracy: 0.8047
# Epoch 94/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9113
# Epoch 94: val_loss did not improve from 0.37129
# 31/31 [==============================] - 192s 6s/step - loss: 0.2219 - accuracy: 0.9113 - val_loss: 0.8559 - val_accuracy: 0.8047
# Epoch 95/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9068
# Epoch 95: val_loss did not improve from 0.37129
# 31/31 [==============================] - 189s 6s/step - loss: 0.2304 - accuracy: 0.9068 - val_loss: 0.7601 - val_accuracy: 0.8203
# Epoch 96/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.9103
# Epoch 96: val_loss did not improve from 0.37129
# 31/31 [==============================] - 194s 6s/step - loss: 0.2247 - accuracy: 0.9103 - val_loss: 0.7933 - val_accuracy: 0.8047
# Epoch 97/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2262 - accuracy: 0.9103
# Epoch 97: val_loss did not improve from 0.37129
# 31/31 [==============================] - 196s 6s/step - loss: 0.2262 - accuracy: 0.9103 - val_loss: 0.7701 - val_accuracy: 0.8203
# Epoch 98/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2148 - accuracy: 0.9133
# Epoch 98: val_loss did not improve from 0.37129
# 31/31 [==============================] - 192s 6s/step - loss: 0.2148 - accuracy: 0.9133 - val_loss: 0.9417 - val_accuracy: 0.7812
# Epoch 99/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2220 - accuracy: 0.9153
# Epoch 99: val_loss did not improve from 0.37129
# 31/31 [==============================] - 191s 6s/step - loss: 0.2220 - accuracy: 0.9153 - val_loss: 0.8196 - val_accuracy: 0.7969
# Epoch 100/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2302 - accuracy: 0.9047
# Epoch 100: val_loss did not improve from 0.37129
# 31/31 [==============================] - 198s 6s/step - loss: 0.2302 - accuracy: 0.9047 - val_loss: 0.7660 - val_accuracy: 0.8203

# %%
# evaluation

# load testing set
test_metadata_filename = "test.csv"
df_test = pd.read_csv(test_metadata_filename)
n_testing_samples = len(df_test)
print("Number of testing samples:", n_testing_samples)
test_ds = tf.data.Dataset.from_tensor_slices((df_test["filepath"], df_test["label"]))

def prepare_for_testing(ds, cache=True, shuffle_buffer_size=1000):
  # This is a small dataset, only load it once, and keep it in memory.
  # use `.cache(filename)` to cache preprocessing work for datasets that don't
  # fit in memory.
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()

  ds = ds.shuffle(buffer_size=shuffle_buffer_size)

  return ds


test_ds = test_ds.map(process_path)
test_ds = prepare_for_testing(test_ds, cache="test-cached-data")
# Out:
# Number of testing samples: 600

# %%
# convert testing set to numpy array to fit in memory (don't do that when testing
# set is too large)
y_test = np.zeros((n_testing_samples,))
X_test = np.zeros((n_testing_samples, 299, 299, 3))
for i, (img, label) in enumerate(test_ds.take(n_testing_samples)):
  # print(img.shape, label.shape)
  X_test[i] = img
  y_test[i] = label.numpy()

print("y_test.shape:", y_test.shape)
# Out:
# y_test.shape: (600,)

# %%
# load the weights with the least loss
#m.load_weights("benign-vs-malignant_64_rmsprop_0.390.h5")

# %%
print("Evaluating the model...")
loss, accuracy = m.evaluate(X_test, y_test, verbose=0)
print("Loss:", loss, "  Accuracy:", accuracy)
# Out:
# Evaluating the model...
# Loss: 0.7663342952728271   Accuracy: 0.8050000071525574

# %%
from sklearn.metrics import accuracy_score

def get_predictions(threshold=None):
  """
  Returns predictions for binary classification given `threshold`
  For instance, if threshold is 0.3, then it'll output 1 (malignant) for that sample if
  the probability of 1 is 30% or more (instead of 50%)
  """
  y_pred = m.predict(X_test)
  if not threshold:
    threshold = 0.5
  result = np.zeros((n_testing_samples,))
  for i in range(n_testing_samples):
    # test melanoma probability
    if y_pred[i][0] >= threshold:
      result[i] = 1
    # else, it's 0 (benign)
  return result

threshold = 0.23
# get predictions with 23% threshold
# which means if the model is 23% sure or more that is malignant,
# it's assigned as malignant, otherwise it's benign
y_pred = get_predictions(threshold)
accuracy_after = accuracy_score(y_test, y_pred)
print("Accuracy after setting the threshold:", accuracy_after)
# Out:
# 19/19 [==============================] - 49s 3s/step
# Accuracy after setting the threshold: 0.8033333333333333

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc, confusion_matrix

def plot_confusion_matrix(y_test, y_pred):
  cmn = confusion_matrix(y_test, y_pred)
  # Normalise
  cmn = cmn.astype('float') / cmn.sum(axis=1)[:, np.newaxis]
  # print it
  print(cmn)
  fig, ax = plt.subplots(figsize=(10,10))
  sns.heatmap(cmn, annot=True, fmt='.2f', 
              xticklabels=[f"pred_{c}" for c in class_names], 
              yticklabels=[f"true_{c}" for c in class_names],
              cmap="Blues"
              )
  plt.ylabel('Actual')
  plt.xlabel('Predicted')
  # plot the resulting confusion matrix
  plt.show()


def plot_roc_auc(y_true, y_pred):
    """
    This function plots the ROC curves and provides the scores.
    """
    # prepare for figure
    plt.figure()
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    # obtain ROC AUC
    roc_auc = auc(fpr, tpr)
    # print score
    print(f"ROC AUC: {roc_auc:.3f}")
    # plot ROC curve
    plt.plot(fpr, tpr, color="blue", lw=2,
                label='ROC curve (area = {f:.2f})'.format(d=1, f=roc_auc))
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curves')
    plt.legend(loc="lower right")
    plt.show()

plot_confusion_matrix(y_test, y_pred)
plot_roc_auc(y_test, y_pred)
#sensitivity = sensitivity_score(y_test, y_pred)
#specificity = specificity_score(y_test, y_pred)

#print("Melanoma Sensitivity:", sensitivity)
#print("Melanoma Specificity:", specificity)
# Out:
# [[0.98757764 0.01242236]
#  [0.95726496 0.04273504]]
# ROC AUC: 0.515

# %%
def plot_images(X_test, y_pred, y_test):
  predicted_class_names = np.array([class_names[int(round(id))] for id in y_pred])
  # some nice plotting
  plt.figure(figsize=(10,9))
  for n in range(30, 60):
      plt.subplot(6,5,n-30+1)
      plt.subplots_adjust(hspace = 0.3)
      plt.imshow(X_test[n])
      # get the predicted label
      predicted_label = predicted_class_names[n]
      # get the actual true label
      true_label = class_names[int(round(y_test[n]))]
      if predicted_label == true_label:
          color = "blue"
          title = predicted_label.title()
      else:
          color = "red"
          title = f"{predicted_label.title()}, true:{true_label.title()}"
      plt.title(title, color=color)
      plt.axis('off')
  _ = plt.suptitle("Model predictions (blue: correct, red: incorrect)")
  plt.show()

plot_images(X_test, y_pred, y_test)
